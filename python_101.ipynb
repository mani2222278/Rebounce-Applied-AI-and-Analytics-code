# %% [markdown]
# <a href="https://colab.research.google.com/github/mani2222278/Rebounce-Applied-AI-and-Analytics-code/blob/main/python_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "priya"
city = "Delhi"
birth_year =  1999
current_year = 2026
age = current_year - birth_year
print(f"Hi, I'm {name}  from {city} This year I turn {age}.")
# Out:
# Hi, I'm priya  from Delhi This year I turn 27.

# %%
int_amount = 75000
exchange_rate = 1.75
yen_received = int_amount * exchange_rate
print(f"Rs {int_amount} converts to yen {yen_received:.2f}")
# Out:
# Rs 75000 converts to yen 131250.00

# %%
bread = 40
milk = 65.50
eggs = 120
total = bread + milk + eggs
average = total / 3
print(f"Total: Rs {total:.2f}")
print(f"Average per item: Rs {average:.2f}")
# Out:
# Total: Rs 225.50
# Average per item: Rs 75.17

# %%
number = 47
#This checks if the remainder is 0 when divided by 2
is_even = (number % 2 == 0)
print(f"is {number} even? {is_even}")
# Out:
# is 47 even? False

# %%
password = "Sunny@567"
length_ok = len(password) >= 8
has_at = "@" in password
is_strong = length_ok and has_at
print("length_OK:",length_ok)
print("Has @:", has_at)
print("strong password:", is_strong)
# Out:
# length_OK: True
# Has @: True
# strong password: True
