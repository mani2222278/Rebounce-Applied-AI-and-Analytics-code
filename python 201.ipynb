# %% [markdown]
# <a href="https://colab.research.google.com/github/mani2222278/Rebounce-Applied-AI-and-Analytics-code/blob/main/python%20201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Track A - Personal Expense Tracker
#
# This program help users record their daily expenses.
# It shows total expensse and category-wise total.
# Run all cells, then call main() to start.

# %%
import json
import os
FILE_NAME = "expenses.json"

# %%
def load_data():
  if os.path.exists(FILE_NAME):
    with open(FILE_NAME, "r") as file:
      return json.load(file)
      return[]

# %%
def save_date(expenses):
  with open(FILE_NAME,"w"):
    json.dump(expenses, file, indent=4)

# %%
def add_expense(expenses):
  category = input("Enter category: ")
  amount = float(input("Enter amount: "))
  description = input("Enter description:")
