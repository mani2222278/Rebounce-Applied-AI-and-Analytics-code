# %% [markdown]
# <a href="https://colab.research.google.com/github/mani2222278/Rebounce-Applied-AI-and-Analytics-code/blob/main/Q1_datatypes_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # S01 - Practice 1: Data Types & Operators

# %% [markdown]
# **Applied AI & Analytics Lab** · Session 1 · Practice notebook 1 of 3
#
# **Time:** about 20-25 minutes.
# **How to use this:** each exercise has a cell with `____` blanks or a `# YOUR CODE HERE` line.
# Fill it in and run it. The expected output is written in the comment.
#
# Do not open the solutions notebook until you have tried every single one.
# Getting it wrong and fixing it **is** the learning. There is no shortcut.
#
# ---

# %% [markdown]
# ### Exercise 1 - Name the type  ·  *easy*
#
# Print the type of each value below.
# Expected output: `<class 'int'>`, `<class 'float'>`, `<class 'str'>`, `<class 'bool'>`

# %%
# Use the type() function on each value.
print(type(11))
print(type(21.213))
print(type("Hello"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ### Exercise 2 - The sneaky dot  ·  *easy*
#
# `1` and `1.0` look almost the same. Python disagrees.
# Print the type of each, and print whether they are equal.

# %%
print(type(1))
print(type(1.2))     # make this a float version of 1

# Are they equal in VALUE? Use the comparison operator.
print(1 == 1.0)
# Out:
# <class 'int'>
# <class 'float'>
# True

# %% [markdown]
# ### Exercise 3 - Casting  ·  *easy*
#
# Convert each value to the type asked for in the comment.

# %%
print(type(2.0))        # int 2 -> float. Expect: 2.0
print(type(3))     # float -> int. Expect: 3
print(type("5"))        # int -> string. Expect: "5"
print(type(42))     # string -> int. Expect: 42
print(type(0))    # bool -> int. Expect: 0
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# ### Exercise 4 - Cut off, not rounded  ·  *easy*
#
# `int()` throws the decimal away. `round()` rounds properly.
# Print both for the value `4.7` and see the difference.

# %%
import math
value = 4.7

print(math.floor(value))    # Expect: 4
print(math.ceil(value))    # Expect: 5
# Out:
# 4
# 5

# %% [markdown]
# ### Exercise 5 - The four divisions  ·  *medium*
#
# Python has more than one kind of division. Print all four results for 17 and 5.

# %%
import math
a = 17
b = 5
remainder = a%b
print(float(a % b))    # normal division. Expect: 3.4
print(math.ceil(a % b) )   # integer division. Expect: 3
print(remainder)    # remainder. Expect: 2
print(a ** b)    # a to the power of b. Expect: 1419857
# Out:
# 2.0
# 2
# 2
# 1419857

# %% [markdown]
# ### Exercise 6 - Order of operations  ·  *medium*
#
# Fix the expression below with brackets so it prints `1920` instead of `150`.

# %%
# Currently this prints 150 because * happens before +.
print(30 + 2 * 60)

# Now make this line print 1920.
print(20 + 950*2)
# Out:
# 150
# 1920

# %% [markdown]
# ### Exercise 7 - Total minutes  ·  *medium*
#
# Three songs are 43, 42 and 57 minutes long.
# Store the total in a variable, then print the total in hours.

# %%
song_1 = 43
song_2 = 42
song_3 = 57

total_minutes = song_1 + song_2 + song_3
total_hours = total_minutes / 60

print("Total minutes:", total_minutes)   # Expect: 142
print("Total hours:", total_hours)       # Expect: 2.3666666666666667
# Out:
# Total minutes: 142
# Total hours: 2.3666666666666667

# %% [markdown]
# ### Exercise 8 - Assign or compare?  ·  *medium*
#
# One of the lines below is a question and one is an instruction.
# Fill in the right operator for each.

# %%
# Instruction: make score equal 90.
score =  90

# Question: is score equal to 90?
print(score == 90)      # Expect: True

# Question: is score NOT equal to 100?
print(score!= 100)     # Expect: True
# Out:
# True
# True

# %% [markdown]
# ### Exercise 9 - Was it from the 80s?  ·  *hard*
#
# Write one expression that is `True` only if `album_year` is between 1980 and 1989 inclusive.
# Test it with both years given.

# %%
album_year = 1982
print(1980<= album_year <=1989)      # Expect: True

album_year = 1991
print(1980<=album_year <=1989)      # Expect: False
# Out:
# True
# False

# %% [markdown]
# ### Exercise 10 - Truth table  ·  *hard*
#
# Fill in the blanks so every line prints `True`.

# %%
print(True == True)        # both must be True
print(True != False)       # only one needs to be True
print(False)            # flip False
print((5 > 3) or (2 > 9))  # one side is False, still want True
# Out:
# True
# True
# False
# True

# %% [markdown]
# ### Exercise 11 - Break it on purpose  ·  *hard*
#
# Each line below causes an error. Run them one at a time (uncomment one, run, re-comment).
# Write down the **name** of the error in the comment. This is a real skill - errors are
# information, not failure.

# %%
# print("5" + 5)  # only concatenate string to string
# print(int("hello"))
# print(10 / 0)
# print(undefined_variable)

# Which error did each one give?
# 1. _concatenate error string to string not string to integer___Error
# 2. _indentation Error
# 3.  Indentation Error
# 4. Indentation Error

# %% [markdown]
# ### Exercise 12 - Your first tiny program  ·  *hard*
#
# A shop sells tea at 10 rupees and coffee at 25 rupees.
# A customer buys 3 teas and 2 coffees. There is 5% GST on the total.
#
# Print the final amount, rounded to 2 decimal places.
# Use variables with clear names - do not just write one long sum.

# %%
# YOUR CODE HERE
tea_price =10
coffee_price = 25

tea_quantity = 3
coffee_quantity = 2

tea_total = tea_price * tea_quantity
coffee_total = coffee_price * coffee_quantity

total_amount = tea_total + coffee_total

gst_amount = total_amount * 0.05

final_amount = total_amount + gst_amount

print(f"Final amount: ,{round(final_amount, 2) } rupees")
# Expected output: Final amount: 84.0
# Out:
# Final amount: ,84.0 rupees

# %% [markdown]
# ---
#
# **Done.** Commit this notebook to your GitHub repository for Minor Project 1.
